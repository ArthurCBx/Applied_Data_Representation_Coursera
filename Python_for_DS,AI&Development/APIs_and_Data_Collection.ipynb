# %% [markdown]
# <a href="https://colab.research.google.com/github/ArthurCBx/Applied_Data_Representation_Coursera/blob/main/Python_for_DS%2CAI%26Development/APIs_and_Data_Collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Application Program Interface
#
# ## What is an API
# - Is a way to communicate your program with other software via inputs
#
# ## REST APIs
# - Representational State Transfer APIs;
# - Used to interact with web services, that is applications that you call through the internet;
# - They have a set of rules regarding:
#   1. Communication;
#   2. Input or Request;
#   3. Output or Response.
#
# - Your code is the client and the Web service is the resource. The client finds the resource via an endpoint;
# - HTTP is a way to send instructions to communicate with the web service, which returns an HTTP.

# %%
# Example
# !pip install -q pycoingecko

# %%
from pycoingecko import CoinGeckoAPI
import pandas as pd
cg = CoinGeckoAPI()
bitcoin_data = cg.get_coin_market_chart_by_id(id="bitcoin", vs_currency="usd",days=30)
df = pd.DataFrame(bitcoin_data['prices'],columns=["timestamp","price"])
df["timestamp"] = pd.to_datetime(df["timestamp"], unit="ms")
df
# Out:
#                   timestamp         price
# 0   2026-01-15 15:03:40.035  96203.139988
# 1   2026-01-15 16:01:54.416  95648.340692
# 2   2026-01-15 17:01:30.921  96711.698605
# 3   2026-01-15 18:02:41.739  96554.471742
# 4   2026-01-15 19:00:55.817  95812.024335
# ..                      ...           ...
# 716 2026-02-14 11:03:23.061  69635.274684
# 717 2026-02-14 12:00:48.924  70434.284634
# 718 2026-02-14 13:03:48.660  69633.026365
# 719 2026-02-14 14:03:05.751  69416.535853
# 720 2026-02-14 14:47:52.000  69626.988786
#
# [721 rows x 2 columns]

# %% [markdown]
# # REST APIs & HTTP Requests
#
# ## HTTP Protocol
# - Outline:
#   - Uniform Resource Locator: URL;
#   - Request;
#   - Response.
#
# ## Uniform Resource Locator (URL)
# - Overview of HTTP:
#   - **Scheme**: The protocol can be `http://`;
#   - **Internet address or Base URL**: Used to find the location, e.g., `www.gitlab.com`
#   - **Route**: Location on the web server, e.g., `/images`
#
# ## Request Message
# - **Request Start Line**: example - /GET/index.html HTTP/1.0
# - **Request Header**: User-Agent: python-requests/2.21.0 Accept-Encoding:gzip, deflate ...
# - **Request Body**
#
# ## Response Message
# - **Response Start Line**: example - HTTP/1.0 200 OK
# - **Response Header**: Server: Apache-Cache: UNCACHEABLE
# - **Response Body**:
# ```
# <!DOCTYPE hmtl>
# <html>
# <body>
# <h1>My First Heading</h1>
# <p>My first paragraph.<p>
# </body>
# </html>
# ```
# ## Status Code
# - 1XX - Informational
#   - 100 - Everything so far is OK
# - 2xx - Sucess
#   - 200 - OK
# - 3XX - Redirection
#   -  300 - Multiple Choices
# - 4XX - Client Error
#   - 401 - Unauthorized
#   - 403 - Forbidden
#   - 404 - Not Found
# - 500 - Server Error
# - 501 - Not Implemented
#
# ## HTTP Methods
# - GET: Retrieves data from the server;
# - POST: Submits data to server
# - PUT: Updates data already on server;
# - DELETE: Delete data from server

# %% [markdown]
# # Requests module in Python

# %%
import requests
url = 'https://www.ibm.com/'
r = requests.get(url)
print(f"Status code of the request: {r.status_code}\n")
print(f"Request Headers:\n{r.headers}\n")
print(f"Request Body:\n{r.request.body}\n")
print(f"Rquest Encoding: {r.encoding}\n")
print(f"Request Text first 50 chars {r.text[0:50]}\n")
# Out:
# Status code of the request: 200
#
# Request Headers:
# {'Content-Security-Policy': 'upgrade-insecure-requests', 'x-frame-options': 'SAMEORIGIN', 'Last-Modified': 'Sat, 14 Feb 2026 18:00:16 GMT', 'ETag': '"31162-64acc7e7f54d5-gzip"', 'Accept-Ranges': 'bytes', 'Content-Type': 'text/html;charset=utf-8', 'X-Content-Type-Options': 'nosniff', 'Cache-Control': 'max-age=600', 'Expires': 'Sat, 14 Feb 2026 22:09:10 GMT', 'X-Akamai-Transformed': '0 - 0 -', 'Content-Encoding': 'gzip', 'Date': 'Sat, 14 Feb 2026 21:59:10 GMT', 'Content-Length': '39760', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'Strict-Transport-Security': 'max-age=31536000'}
#
# Request Body:
# None
#
# Rquest Encoding: utf-8
#
# Request Text first 50 chars
# <!DOCTYPE HTML>
#
# <html lang="en">
# <head>

# %% [markdown]
# ## Get request with URL parameters

# %%
# Create query string
url_get = "http://httpbin.org/get"
payload={"name":"Joseph", "ID": "123"}
r = requests.get(url_get, params=payload)
print(f"URL: {r.url}")
print(f"Status: {r.status_code}")
print(f"Text: {r.text}")
print(f"Json: {r.json}")
# Out:
# URL: http://httpbin.org/get?name=Joseph&ID=123
# Status: 200
# Text: {
#   "args": {
#     "ID": "123",
#     "name": "Joseph"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br, zstd",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-6990f15e-74bdef1208fdd3ff40f3daa3"
#   },
#   "origin": "34.139.86.234",
#   "url": "http://httpbin.org/get?name=Joseph&ID=123"
# }
#
# Json <bound method Response.json of <Response [200]>>

# %%
# Simple post example
url_post = "http://httpbin.org/post"
payload = {"name":"Joseph", "ID":"123"}
r_post = requests.post(url_post, data=payload)
print(f"URL: {r_post.url}")
print(f"Status: {r_post.status_code}")
print(f"Text: {r_post.text}")
# Out:
# URL: http://httpbin.org/post
# Status: 200
# Text: {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "ID": "123",
#     "name": "Joseph"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br, zstd",
#     "Content-Length": "18",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.4",
#     "X-Amzn-Trace-Id": "Root=1-6990f1eb-07b55d552988c44c68acde45"
#   },
#   "json": null,
#   "origin": "34.139.86.234",
#   "url": "http://httpbin.org/post"
# }

# %% [markdown]
# ## Using BeautifulSoup to parse html content

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://en.wikipedia.org/wiki/IBM'

# Set a User-Agent header to avoid being blocked by Wikipedia
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
}

response = requests.get(url, headers=headers)
html_content = response.text

# Create a BeautifulSoup object to parse the HTML
soup = BeautifulSoup(html_content, 'html.parser')
print(f"Page Title: {soup.title.text}")
# Out:
# Page Title: IBM - Wikipedia

# %%
# Extract the title of the page
# Out:
# Page Title: IBM - Wikipedia

# %% [markdown]
# # HTML for Web Scrapping
# ## HTML Tables
# ```
# <table>
#   <tr>
#     <td>row 1</td>
#     <td>row 2</td>
#   </tr>
#   <tr>
#     <td>row 1</td>
#     <td>row 2</td>
#   </tr>
# </table>
# ```
#
# ## Web Scrapping

# %%
from bs4 import BeautifulSoup
html = "<!DOCTYPE hmtl><html><head><title>PageTitle</title></head> ..."

soup = BeautifulSoup(html, 'html5lib')
tag_object=soup.h3
table_row = soup.find_all(name='tr')

# %%
import requests
page = requests.get("https://pt.wikipedia.org/wiki/Wikipédia").text

soup = BeautifulSoup(page, "html.parser")

# Pulls all instances of <a> tag
artists = soup.find_all('a')

# Clears data of all tags
for artist in artists:
  names = artists.contents[0]
  fullLink = artists.get('href')
  print(names)
  print(fullLink)

# %% [markdown]
# # Working with Different File Formats
#
# ## CSV files
# ```python
# import pandas as pd
# file = "FileExample.csv"
# df = pd.read_csv(file)
# ```
#
# ## JSON files
# ```python
# import json
# with open('filesample.json','r') as openfile:
#   json_object = json.load(openfile)
# ```
#
# ## XML files
# ```python
# import pandas as pd
# file = "FileExample.xml"
# pd.read_xml(file)
# ```

# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %% [markdown]
# <h2 id="BSO">Beautiful Soup Objects</h2>

# %% [markdown]
# Beautiful Soup is a Python library for pulling data out of HTML and XML files, we will focus on HTML files. This is accomplished by representing the HTML as a set of objects with methods used to parse the HTML.  We can navigate the HTML as a tree, and/or filter out what we are looking for.
#
# Consider the following HTML:

# %%
html="<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>"
# To parse a document, pass it into the BeautifulSoup constructor. The BeautifulSoup object
# represents the document as a nested data structure:

soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# First, the document is converted to Unicode (similar to ASCII) and HTML entities are converted to Unicode characters. Beautiful Soup transforms a complex HTML document into a complex tree of Python objects. The <code>BeautifulSoup</code> object can create other types of objects. In this lab, we will cover <code>BeautifulSoup</code> and <code>Tag</code> objects, that for the purposes of this lab are identical. Finally, we will look at <code>NavigableString</code> objects.

# %%
# We can use the method <code>prettify()</code> to display the HTML in the nested structure:
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h3>
#    <b id="boldest">
#     Lebron James
#    </b>
#   </h3>
#   <p>
#    Salary: $ 92,000,000
#   </p>
#   <h3>
#    Stephen Curry
#   </h3>
#   <p>
#    Salary: $85,000, 000
#   </p>
#   <h3>
#    Kevin Durant
#   </h3>
#   <p>
#    Salary: $73,200, 000
#   </p>
#  </body>
# </html>

# %% [markdown]
# Let's say we want the  title of the page and the name of the top paid player. We can use the <code>Tag</code>. The <code>Tag</code> object corresponds to an HTML tag in the original document, for example, the tag title.

# %%
tag_object=soup.title
print("tag object:",tag_object)
print("tag object type:",type(tag_object))
# Out:
# tag object: <title>Page Title</title>
# tag object type: <class 'bs4.element.Tag'>

# %% [markdown]
# If there is more than one <code>Tag</code> with the same name, the first element with that <code>Tag</code> name is called. This corresponds to the most paid player:

# %%
tag_object=soup.h3
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
#

# %% [markdown]
# # Practice Project: GDP Data extraction and processing
#
# Estimated time needed: **30** minutes
#
# ## Introduction
#
# In this practice project, you will put the skills acquired through the course to use. You will extract data from a website using webscraping and reqeust APIs process it using Pandas and Numpy libraries.

# %% [markdown]
# ## Project Scenario:
#
# An international firm that is looking to expand its business in different countries across the world has recruited you. You have been hired as a junior Data Engineer and are tasked with creating a script that can extract the list of the top 10 largest economies of the world in descending order of their GDPs in Billion USD (rounded to 2 decimal places), as logged by the International Monetary Fund (IMF).
#
# The required data seems to be available on the URL mentioned below:

# %%
URL="https://web.archive.org/web/20230902185326/https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29"

# %% [markdown]
# You can use Pandas library to extract the required table directly as a DataFrame. Note that the required table is the third one on the website, as shown in the image below.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/images/pandas_wbs_3.png">

# %%
import pandas as pd

URL="https://web.archive.org/web/20230902185326/https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29"

# Extract tables from webpage using Pandas. Retain table number 3 as the required dataframe.
df = pd.read_html(URL)
df = df[3]

# Replace the column headers with column numbers

df.columns = range(df.shape[1])

# Retain columns with index 0 and 2 (name of country and value of GDP quoted by IMF)
df = df[[0, 2]]

# Retain the Rows with index 1 to 10, indicating the top 10 economies of the world.
df = df.iloc[1:11]

# Assign column names as "Country" and "GDP (Million USD)"
df.columns=['Country', 'GDP']
df
# Out:
#            Country       GDP
# 1    United States  26854599
# 2            China  19373586
# 3            Japan   4409738
# 4          Germany   4308854
# 5            India   3736882
# 6   United Kingdom   3158938
# 7           France   2923489
# 8            Italy   2169745
# 9           Canada   2089672
# 10          Brazil   2081235

# %% [markdown]
# ### Exercise 2
# Modify the GDP column of the DataFrame, converting the value available in Million USD to Billion USD. Use the `round()` method of Numpy library to round the value to 2 decimal places. Modify the header of the DataFrame to `GDP (Billion USD)`.

# %%
df['GDP'] = df['GDP'].astype(int)
df['GDP'] = round(df['GDP']/1000, 2)
df = df.rename(columns={"GDP": "GDP (Billion USD)"})
df
# Out:
#            Country  GDP (Billion USD)
# 1    United States           26854.60
# 2            China           19373.59
# 3            Japan            4409.74
# 4          Germany            4308.85
# 5            India            3736.88
# 6   United Kingdom            3158.94
# 7           France            2923.49
# 8            Italy            2169.74
# 9           Canada            2089.67
# 10          Brazil            2081.24

# %% [markdown]
# Load the DataFrame to the CSV file named "Largest_economies.csv"

# %%
df.to_csv("Largest_economies.csv")
